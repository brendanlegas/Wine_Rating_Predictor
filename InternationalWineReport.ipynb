# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

#URl
wine_url = 'https://www.internationalwinereport.com/top100-2019'

wine_listing_df, = pd.read_html(wine_url,header=0)

wine_listing_df
# Out:
#      Rank                                         Unnamed: 1 Rank.1  Country  \
# 0     1.0  LARKMEAD Cabernet Sauvignon, Napa Valley 'The ...     #1      NaN
# 1     2.0       CHÂTEAU LEOVILLE LAS CASES Saint-Julien 2016     #2      NaN
# 2     3.0  EGON MÜLLER Riesling Spätlese, Scharzhofberger...     #3      NaN
# 3     4.0                    TENUTA SAN GUIDO Sassicaia 2016     #4      NaN
# 4     5.0  PIERRE PÉTERS Champagne, Blanc de Blancs Grand...     #5      NaN
# ..    ...                                                ...    ...      ...
# 95   97.0                  ALHEIT VINEYARDS 'Cartology' 2017    #97      NaN
# 96   98.0      ORNELLAIA Bolgheri Superiore 'Ornellaia' 2016    #98      NaN
# 97   99.0                DOMAINE LAURENT TRIBUT Chablis 2017    #99      NaN
# 98  100.0  BRICK & MORTAR Brut Rosé, Sweetwater Springs V...   #100      NaN
# 99    NaN                                                NaN    NaN      NaN
#
# ...

# %%
cleaner = wine_listing_df[['Unnamed:1','']]
